# %%
import pandas as pd
import requests
from collections import Counter
from sf_parks.models import FilmLocations, PrivateOpenSpaces
from sf_parks.data import (
    insert_into_db,
    film_locations,
    park_scores,
    private_open_spaces,
    properties
)

pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Check contents of datasets

# %%
def check_key_counts(json_data):
    print(f'number of records: {len(json_data)}')
    keys = Counter()
    for record in json_data:
        for k in record:
            keys[k] += 1
    return keys

# %%
check_key_counts(film_locations)
# Out:
# number of records: 1000
# Counter({'title': 1000,
#          'release_year': 1000,
#          'locations': 975,
#          'production_company': 1000,
#          'director': 1000,
#          'writer': 1000,
#          'actor_1': 996,
#          'actor_2': 974,
#          'actor_3': 790,
#          'address': 975,
#          'distributor': 945,
#          'fun_facts': 236})

# %%
check_key_counts(park_scores)
# Out:
# number of records: 1000
# Counter({'parkid': 1000, 'psa': 1000, 'park': 1000, 'fq': 1000, 'score': 1000})

# %%
check_key_counts(private_open_spaces)
# Out:
# number of records: 78
# Counter({'name': 78,
#          'popos_address': 78,
#          'hours': 72,
#          'type': 78,
#          'landscaping': 70,
#          'seating_no': 71,
#          'food_service': 73,
#          'art': 71,
#          'restrooms': 72,
#          'accessibility': 72,
#          'location': 53,
#          'year': 78,
#          'description': 72,
#          'seating_and_tables': 22,
#          'hours_type': 76,
#          'subject_to_downtown_pln': 78,
#          'signage': 74,
#          'block_num': 78,
#          'lot_num': 78,
#          'parcel_num': 78,
#          'the_geom': 78,
#          ':@computed_region_6qbp_sg9q': 78,
#          ':@computed_region_qgnn_b9vv': 78,
#          ':@computed_region_26cr_cadq': 78,
#          ':@computed_region_ajp5_b2md': 78,
#          ':@computed_region_rxqg_mtj9': 78,
#          ':@computed_region_yftq_j783': 78,
#          ':@computed_region_jx4q_fizf': 78,
#          ':@computed_region_bh8s_q3mv': 78,
#          ':@computed_region_jwn9_ihcz': 78,
#          'latitude': 78,
#          'longitude': 78,
#          'sf_find_neighborhoods': 78,
#          'current_police_districts': 78,
#          'current_supervisor_districts': 78,
#          'analysis_neighborhoods': 78,
#          'food': 50,
#          'seating': 68,
#          'restroom': 43,
#          'amenities': 5,
#          'indoor': 14,
#          'special_amenities': 5})

# %%
check_key_counts(properties)
# Out:
# number of records: 240
# Counter({'objectid': 240,
#          'map_label': 240,
#          'longitude': 240,
#          'latitude': 240,
#          'acres': 240,
#          'tma_propertyid': 240,
#          'globalid': 240,
#          'created_user': 240,
#          'created_date': 240,
#          'last_edited_user': 240,
#          'last_edited_date': 240,
#          'squarefeet': 240,
#          'perimeterlength': 240,
#          'propertytype': 240,
#          'address': 240,
#          'city': 240,
#          'state': 240,
#          'zipcode': 240,
#          'complex': 240,
#          'psa': 240,
#          'supdist': 240,
#          'ownership': 239,
#          'land_id': 238,
#          'ggp_section': 237,
#          'state_senate': 237,
#          'mons_neighborhood': 240,
#          'police_district': 237,
#          'us_congress': 237,
#          'realtor_neighborhood': 239,
#          'state_assembly': 237,
#          'planning_neighborhood': 240,
#          'shape': 240})

# %% [markdown]
# ## Explore Datasets

# %%
film_locations_df = pd.DataFrame(film_locations)
park_scores_df = pd.DataFrame(park_scores)
private_open_spaces_df = pd.DataFrame(private_open_spaces)
properties_df = pd.DataFrame(properties)

# %% [markdown]
# `park_scores` and `properties` might be able to be joined with `park_scores.parkid` = `properties.tma_propertyid`.

# %%
park_scores_and_prop_df = park_scores_df.set_index('parkid').join(properties_df.set_index('tma_propertyid'), rsuffix='_prop')
park_scores_and_prop_df
# Out:
#      psa                   park      fq                score objectid  \
# 1   PSA5              Glen Park  FY05Q4  0.85799999999999998    17064
# 1   PSA5              Glen Park  FY06Q2                 0.99    17064
# 1   PSA5              Glen Park  FY06Q4  0.96299999999999997    17064
# 1   PSA5              Glen Park  FY07Q2                0.876    17064
# 1   PSA5              Glen Park  FY08Q2                    1    17064
# ..   ...                    ...     ...                  ...      ...
# 99  PSA1  Rochambeau Playground  FY06Q3  0.95799999999999996       33
# 99  PSA1  Rochambeau Playground  FY07Q1                0.754       33
# 99  PSA1  Rochambeau Playground  FY07Q3  0.92200000000000004       33
# 99  PSA1  Rochambeau Playground  FY08Q1  0.92600000000000005       33
# 99  PSA1  Rochambeau Playground  FY08Q2  0.89100000000000001       33
#
#                 map_label      longitude     latitude        acres  \
# 1        Glen Canyon Park  -122.44266629  37.74020594  77.93628414
# 1        Glen Canyon Park  -122.44266629  37.74020594  77.93628414
# 1        Glen Canyon Park  -122.44266629  37.74020594  77.93628414
# 1        Glen Canyon Park  -122.44266629  37.74020594  77.93628414
# 1        Glen Canyon Park  -122.44266629  37.74020594  77.93628414
# ..                    ...            ...          ...          ...
# 99  Rochambeau Playground   -122.4845337  37.78483899    0.9086263
# 99  Rochambeau Playground   -122.4845337  37.78483899    0.9086263
# 99  Rochambeau Playground   -122.4845337  37.78483899    0.9086263
# 99  Rochambeau Playground   -122.4845337  37.78483899    0.9086263
# 99  Rochambeau Playground   -122.4845337  37.78483899    0.9086263
#
#                                   globalid  ... land_id ggp_section  \
# 1   {9DBAB79F-33D3-48C4-B95B-756B4EE39079}  ...       8         N/A
# 1   {9DBAB79F-33D3-48C4-B95B-756B4EE39079}  ...       8         N/A
# 1   {9DBAB79F-33D3-48C4-B95B-756B4EE39079}  ...       8         N/A
# 1   {9DBAB79F-33D3-48C4-B95B-756B4EE39079}  ...       8         N/A
# 1   {9DBAB79F-33D3-48C4-B95B-756B4EE39079}  ...       8         N/A
# ..                                     ...  ...     ...         ...
# 99  {2321DDCD-92E8-424B-8EDD-D82091A67FAD}  ...     190         N/A
# 99  {2321DDCD-92E8-424B-8EDD-D82091A67FAD}  ...     190         N/A
# 99  {2321DDCD-92E8-424B-8EDD-D82091A67FAD}  ...     190         N/A
# 99  {2321DDCD-92E8-424B-8EDD-D82091A67FAD}  ...     190         N/A
# 99  {2321DDCD-92E8-424B-8EDD-D82091A67FAD}  ...     190         N/A
#
#                 state_senate mons_neighborhood police_district  \
# 1   11th Senatorial District         Glen Park       Ingleside
# 1   11th Senatorial District         Glen Park       Ingleside
# 1   11th Senatorial District         Glen Park       Ingleside
# 1   11th Senatorial District         Glen Park       Ingleside
# 1   11th Senatorial District         Glen Park       Ingleside
# ..                       ...               ...             ...
# 99  11th Senatorial District       Lake Street        Richmond
# 99  11th Senatorial District       Lake Street        Richmond
# 99  11th Senatorial District       Lake Street        Richmond
# 99  11th Senatorial District       Lake Street        Richmond
# 99  11th Senatorial District       Lake Street        Richmond
#
#                     us_congress       realtor_neighborhood  \
# 1   12th Congressional District  Diamond Heights,Glen Park
# 1   12th Congressional District  Diamond Heights,Glen Park
# 1   12th Congressional District  Diamond Heights,Glen Park
# 1   12th Congressional District  Diamond Heights,Glen Park
# 1   12th Congressional District  Diamond Heights,Glen Park
# ..                          ...                        ...
# 99  12th Congressional District                Lake Street
# 99  12th Congressional District                Lake Street
# 99  12th Congressional District                Lake Street
# 99  12th Congressional District                Lake Street
# 99  12th Congressional District                Lake Street
#
#             state_assembly planning_neighborhood  \
# 1   17th Assembly District       Diamond Heights
# 1   17th Assembly District       Diamond Heights
# 1   17th Assembly District       Diamond Heights
# 1   17th Assembly District       Diamond Heights
# 1   17th Assembly District       Diamond Heights
# ..                     ...                   ...
# 99  19th Assembly District        Outer Richmond
# 99  19th Assembly District        Outer Richmond
# 99  19th Assembly District        Outer Richmond
# 99  19th Assembly District        Outer Richmond
# 99  19th Assembly District        Outer Richmond
#
#                                                 shape
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# ..                                                ...
# 99  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 99  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 99  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 99  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 99  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
#
# [1000 rows x 35 columns]

# %%
private_open_spaces_df
# Out:
#                                             name  \
# 0                                  1 Bush Street
# 1                               Crocker Galleria
# 2                                  301 Howard St
# 3                                71 Stevenson St
# 4                              100 California St
# 5                                  525 Market St
# 6                                    100 Pine St
# 7                                  180 Howard St
# 8                               456 Montomery St
# 9                                49 Stevenson St
# 10                                   50 Beale St
# 11            Marriott Courtyard - A (Starbucks)
# 12                                 425 Market St
# 13                             200 California St
# 14                                 611 Folsom St
# 15                                    100 1st St
# 16                                Marathon Plaza
# 17                    Foundry Square SW (indoor)
# 18                         345 California St - A
# 19                                 595 Market St
# 20                             Foundry Square NW
# 21                        Golden Gate University
# 22                                 120 Howard St
# 23                             150 California St
# 24                                   Hampton Inn
# 25                              50 California St
# 26                              55 Second St - C
# 27                              55 Second St - A
# 28                                    250 Howard
# 29                               77 Van Ness Ave
# 30                            Spear Street Plaza
# 31            Marriott Courtyard - B (Starbucks)
# 32                        Marriott Courtyard - C
# 33                                     1 Post St
# 34                                   Empire Park
# 35                                 235 Second St
# 36                             650 California St
# 37                             Foundry Square SE
# 38                                201 Mission St
# 39                                 14 Fremont St
# 40                              55 Second St - B
# 41                                    222 2nd St
# 42                                   221 Main St
# 43                                  25 Jessie St
# 44                                   135 Main St
# 45                               1 California St
# 46                             600 California St
# 47                                123 Mission St
# 48                             555/557 Market St
# 49                                   211 Main St
# 50                   Foundry Square SW (outdoor)
# 51                                   181 Fremont
# 52  Westfield Sky Terrace (Wesfield Center Mall)
# 53                                 333 Market St
# 54                                 Trinity Alley
# 55                         Millenium Tower Plaza
# 56                                350 Mission St
# 57                                  Redwood Park
# 58             Embarcadero Center West 1, 2, & 3
# 59                                199 Fremont St
# 60                                    101 2nd St
# 61                              Citygroup Center
# 62                    345 California St - West C
# 63                                   77 Beale St
# 64                                   1 Kearny St
# 65                                  201 Spear St
# 66                             101 California St
# 67                                555 Mission St
# 68                             Foundry Square NE
# 69                                   343 Sansome
# 70      Commercial Street (235 Pine Entitlement)
# 71                                   1 Market St
# 72                                444 Market  St
# 73                                560 Mission St
# 74                                 Rincon Center
# 75                             555 California St
# 76                    345 California St - East B
# 77                                  Gap Building
#
#                      popos_address  \
# 0                    1 Bush Street
# 1                    165 Sutter St
# 2                    301 Howard St
# 3                  71 Stevenson St
# 4                100 California St
# 5                    525 Market St
# 6                      100 Pine St
# 7                    180 Howard St
# 8                456 Montgomery St
# 9                  49 Stevenson St
# 10                     50 Beale St
# 11                      299 2nd St
# 12                   425 Market St
# 13               200 California St
# 14                   611 Folsom St
# 15                      100 1st St
# 16                   303 Second St
# 17  505-525 Howard St (200 1st St)
# 18               345 California St
# 19                   595 Market St
# 20                   500 Howard St
# 21                  536 Mission St
# 22                   120 Howard St
# 23               150 California St
# 24              942 Mission Street
# 25                50 California St
# 26                    55 Second St
# 27                    55 Second St
# 28                      250 Howard
# 29                 77 Van Ness Ave
# 30                    160 Spear St
# 31                      299 2nd St
# 32                      299 2nd St
# 33                       1 Post St
# 34               642 Commercial St
# 35                   235 Second St
# 36               650 California St
# 37                   405 Howard St
# 38                  201 Mission St
# 39                   14 Fremont St
# 40                    55 Second St
# 41                      222 2nd St
# 42                     221 Main St
# 43                    25 Jessie St
# 44                     135 Main St
# 45                 1 California St
# 46               600 California St
# 47                  123 Mission St
# 48               555/557 Market St
# 49                     211 Main St
# 50  505-525 Howard St (200 1st St)
# 51                     181 Fremont
# 52                   845 Market St
# 53                   333 Market St
# 54                     333 Bush St
# 55                  301 Mission St
# 56                  350 Mission St
# 57               535 Washington St
# 58          1-5 Embarcadero Center
# 59                  199 Fremont St
# 60                      101 2nd St
# 61                    1 Sansome St
# 62               345 California St
# 63                     77 Beale St
# 64                     1 Kearny St
# 65                    201 Spear St
# 66           101 California Street
# 67                  555 Mission St
# 68                   400 Howard St
# 69                  343 Sansome St
# 70                     235 Pine St
# 71                     1 Market St
# 72                   444 Market St
# 73                  560 Mission St
# 74                    121 Spear St
# 75               555 California St
# 76               345 California St
# 77                     2 Folsom St
#
#                                                 hours  \
# 0                                   Open at all times
# 1                                      6AM-7PM, M-SAT
# 2                                   Open at all times
# 3                                   Open at all times
# 4                                   Open at all times
# 5                                   Open at all times
# 6                                                 NaN
# 7                                      8AM - 6PM, M-F
# 8                                   Open at all times
# 9                                   Open at all times
# 10                                  Open at all times
# 11                                  Open at all times
# 12                                  Open at all times
# 13                                  Open at all times
# 14                                  Open at all times
# 15  Ground level arcade space accessible at all ti...
# 16                                  Open at all times
# 17                                     8AM - 6PM, M-F
# 18                                  Open at all times
# 19                                  Open at all times
# 20                                  Open at all times
# 21                                  Open at all times
# 22                                     8AM - 6PM, M-F
# 23                                       9AM-6PM, M-F
# 24                                      10AM-5PM, M-F
# 25                                  Open at all times
# 26                                     8AM - 6PM, M-F
# 27                                     8AM - 6PM, M-F
# 28                                                NaN
# 29                                     8AM - 6PM, M-F
# 30                                  Open at all times
# 31                                    8:00am - 5:00pm
# 32                                                NaN
# 33                                                NaN
# 34                                    Daylight Hours.
# 35                                     8AM - 6PM, M-F
# 36                                  Open at all times
# 37                                     8AM - 6PM, M-F
# 38                                                NaN
# 39                                  Open at all times
# 40                                     8AM - 6PM, M-F
# 41                                     8AM - 6PM, M-F
# 42                                  Open at all times
# 43                                  Open at all times
# 44        Unknown. Security would not disclose hours.
# 45                                  Open at all times
# 46                                  Open at all times
# 47                                  Open at all times
# 48                                  Open at all times
# 49                                  Open at all times
# 50                                     8AM - 6PM, M-F
# 51                                        8AM-6PM M-F
# 52                                        9AM-5PM M-F
# 53                                  Open at all times
# 54                                  Open at all times
# 55                                     8AM - 6PM, M-F
# 56                                       8AM-5PM, M-F
# 57                      Not posted. Closes before 6pm
# 58                                  Open at all times
# 59                                  Open at all times
# 60                                     8AM - 6PM, M-F
# 61                                                NaN
# 62                                  Open at all times
# 63                                  Open at all times
# 64                                      10AM-5PM, M-F
# 65                                  Open at all times
# 66                                  Open at all times
# 67                                  Open at all times
# 68                                     8AM - 6PM, M-F
# 69                                      10AM-5PM, M-F
# 70                                  Open at all times
# 71                                  Open at all times
# 72                                  Open at all times
# 73                                  Open at all times
# 74                                  Open at all times
# 75                                  Open at all times
# 76                                  Open at all times
# 77                                  Open at all times
#
#                                                  type  \
# 0                                        Urban Garden
# 1                                         Sun Terrace
# 2                                        Urban Garden
# 3                                 Pedestrian Walkways
# 4                                               Plaza
# 5                                        Urban Garden
# 6                                        Urban Garden
# 7                                 Pedestrian Walkways
# 8                                               Plaza
# 9                                  Pedestrian Walkway
# 10                                              Plaza
# 11                                            Snippet
# 12                                       Urban Garden
# 13          Public Sitting Area in Pedestrian Walkway
# 14                                              Plaza
# 15                  Sun Terrace, Indoor Park, Snippet
# 16                                       Urban Garden
# 17                                        Indoor Park
# 18                                              Plaza
# 19                                              Plaza
# 20                                              Plaza
# 21                                            Snippet
# 22                               Uban Garden, Snippet
# 23                                        Sun Terrace
# 24                                       View Terrace
# 25                                            Snippet
# 26                                             Atrium
# 27                                        Indoor Park
# 28                    Urban Park (under construction)
# 29                                        Indoor Park
# 30                                       Urban Garden
# 31                                            Snippet
# 32  Interior courtyard area - does not appear to b...
# 33                                            Snippet
# 34                                         Urban Park
# 35                                 Plaza, Indoor Park
# 36                                              Plaza
# 37                                              Plaza
# 38                                       Urban Garden
# 39                                Pedestrian Walkways
# 40                                            Snippet
# 41                                         Greenhouse
# 42                                              Plaza
# 43                                Pedestrian Walkways
# 44                                        Indoor Park
# 45                                            Snippet
# 46                                            Snippet
# 47                                       Urban Garden
# 48                                       Urban Garden
# 49                                              Plaza
# 50                                              Plaza
# 51                                        Indoor Park
# 52                                        Sun Terrace
# 53                                              Plaza
# 54                                Pedestrian Walkways
# 55                                      Atrium, Plaza
# 56  Interior open space at ground level, specific ...
# 57                                         Urban Park
# 58        Pedestrian walkway on ground and 2nd levels
# 59                                       Urban Garden
# 60                                         Greenhouse
# 61                                             Atrium
# 62                                            Snippet
# 63                                              Plaza
# 64                                        Sun Terrace
# 65                                       Urban Garden
# 66                                              Plaza
# 67                                              Plaza
# 68                                              Plaza
# 69                  View Terrace, Public Sitting Area
# 70  Snippet and lunchtime conversion. Commission w...
# 71                                   Plaza and Atrium
# 72                                              Plaza
# 73                                 Plaza, Indoor Park
# 74                                        Indoor Park
# 75                                       Urban Garden
# 76                                            Snippet
# 77                                       Urban Garden
#
#                                           landscaping  \
# 0   Willow Trees and planting. Interseting archite...
# 1   8 large planter with trees, shrubbery around e...
# 2                                                 NaN
# 3              Marble paving, potted plants, fountain
# 4                                     Pots of flowers
# 5   Plant wall, water feature, abundant street tre...
# 6                                Planting and flowers
# 7         Trees and wall of planters with tall grass.
# 8                  Few spare plantings, water feature
# 9                  No plants, some interesting paving
# 10     30+ trees, large open planters, attracts birds
# 11        Street trees, planters with bushes, flowers
# 12           15 trees, 12 large planters with flowers
# 13   planter box. Good diversity and volume of plants
# 14  7 trees, 6 bushes on sidewalk. Interesting arc...
# 15  Many trees and plants, water feature, fake gra...
# 16  Real grass lawns, some planters, large water f...
# 17                                            8 trees
# 18                          Planters with a few trees
# 19               No landscaping or spatial definition
# 20                      8 trees, palm plant planters,
# 21                                                 No
# 22                                             plants
# 23  Abundant purple plantings, but they take up ma...
# 24           6 empty planters, great views of skyline
# 25  Good tree cover and plantings, define space an...
# 26  A few planters, interesting paving, Art on walls.
# 27        Increase in potted plant number and variety
# 28                                                NaN
# 29                                               None
# 30            Diverse grasses, trees, and green wall.
# 31        Street trees, planters with bushes, flowers
# 32                                  Trees and flowers
# 33                                                NaN
# 34  Water fountain and lots of plants and shade. D...
# 35  Bamboo and street trees protect space from sid...
# 36                                                NaN
# 37                                            8 trees
# 38                                                NaN
# 39                  ~20 small succulent planter boxes
# 40  Plants and trees, uses plant wall to shield us...
# 41      No plants, but warm wood walls, striking art.
# 42                             Succulents and grasses
# 43  Great variety of plants, water feature, elevat...
# 44       Waterfall on glass, some white noise effect.
# 45                                 One tree, minimal.
# 46                    Flowers, succulents, shrubbery.
# 47                                trees and waterfall
# 48        Diverse plants, grasses, and water feature.
# 49                              Shrubs and some trees
# 50                                            8 trees
# 51             2 trees along wall, interesting paving
# 52  Wall planters and 15 basic planters. Great views.
# 53   1 large tree and shrub planters, mostly concrete
# 54            Living plant wall, trees, tall grasses.
# 55              4 trees with lights, 10 medium plants
# 56                       fake trees and grass indoors
# 57  Many redwood trees, diverse ground cover and p...
# 58                      Trees, ferns, arbor, planters
# 59                 15 trees, large planters, boulders
# 60                           4 large trees and plants
# 61                                                NaN
# 62                          Planters with a few trees
# 63  20+ planter trees, open planters, waterfall fe...
# 64                  Hedges and other types of plants.
# 65                                                NaN
# 66  Beautifl terraced seating with abundant plantings
# 67                  9 trees, permeable gravel, bushes
# 68                                            8 trees
# 69  Abundant flower planters, 6 shading trees, int...
# 70                        5 street trees, 14 planters
# 71                                                NaN
# 72  Trees create space definition but space is mos...
# 73                               bamboo, other trees.
# 74  Decomposed granite, trees in corners, minimal ...
# 75  Tall grasses and shrubs, central pool surround...
# 76                          Planters with a few trees
# 77                                   Trees and plants
#
#                                            seating_no  \
# 0                                 None besides steps.
# 1                           24 benches measuring 7'8"
# 2                                                 NaN
# 3   Evidence that there was seating during the day...
# 4   16 movable chairs, 4 tables, 52' of bench seating
# 5   168' platform/box seating, 164' terraced steps...
# 6                                                 NaN
# 7                                     12 linear seats
# 8   72' linear seating, 8 movable chairs and 2 tables
# 9   20 chairs, taken inside before 5pm at time of ...
# 10  40 bench seats; 100+ linear feet of planter se...
# 11       6 linear seats on two benches along sidewalk
# 12             8 backed benches at 7'8"; 4 6' benches
# 13                                          24 linear
# 14                     >200' deep brick ledge seating
# 15  52 movable seats at 10 tables plus numerous ar...
# 16  33 tables with 66 movable chairs, >200' bench ...
# 17  25 movable seats, 6 tables, 47 linear bench seats
# 18            14 chairs, 5 tables, 50' linear seating
# 19  Public seating only on stairs. Restaurant domi...
# 20  44 linear seating on ledges, 21 seating on pla...
# 21                           200+ ft. of linear bench
# 22                                              None.
# 23   9 tables with 36 movable chairs. ~82 ledge seats
# 24  Yes- 6 benches, with a capacity of 74 persons,...
# 25  14 movable chairs, 117 linear ft. of bench, an...
# 26  4 benches (8 seats) along walls of gallery space.
# 27               62 movable chairs and 27 bench seats
# 28                                                NaN
# 29                     3 tables with 9 movable chairs
# 30  Ledges around green spaces and 28 movable chai...
# 31                                          15 chairs
# 32                              42 chairs with tables
# 33                                                NaN
# 34  15 chairs w/ tables, 8 bench seats in the park...
# 35                            42 chairs and 15 tables
# 36                                                NaN
# 37  44 movable chairs, 45 linear seats on planter ...
# 38                                                NaN
# 39  13 large tables, 27 small tables, 16 bench sea...
# 40  Movable furniture removed; only ~100 ft. of pl...
# 41  63 movable chairs, 15 tables, 300+ linear ft. ...
# 42                               24' of linear seats.
# 43  Ledges around the water feature (>100 linear f...
# 44  Ample indoor seating: four tables with movable...
# 45  12 tables with 46 non-movable chairs. 38 linea...
# 46                          37 seats, 28 are movable.
# 47                                   122 linear seats
# 48                                         No Seating
# 49                                  50' linear seats.
# 50  25 movable seats, 6 tables, 47 linear bench seats
# 51  ~20 movable seats around 6 tables. Some are hi...
# 52  32 tables, 47 movable chairs, 11 movable cushi...
# 53                                105' linear seating
# 54             ~ 50 linear seats with movable tables.
# 55              41 movable chairs and 24 linear seats
# 56  35 linear bench seats + amphitheater seating (...
# 57  100+ linear seats on boxes, room for 30+ on st...
# 58  30 tables, 107 chairs, plus planter-side seati...
# 59  Rock planter box seating. Approx 114 linear se...
# 60  25 linear seats on bench/  ledge. 23 tables, 6...
# 61       Ample seating at tables with movable chairs.
# 62            16 chairs, 5 tables, 50' linear seating
# 63  200+ linear feet of planter seating, varying h...
# 64       10 6' benches, approximately 20 linear seats
# 65                                                NaN
# 66  ~1000 linear ft. of seating on terraced steps,...
# 67                      100 linear seats and benches.
# 68                        20 linear seats, 24 movable
# 69  10 tables with 20 movable chairs, 48 linear be...
# 70  8 public seats (bench and planter seats) and m...
# 71                                   16 small benches
# 72  8 movable chairs, 4 tables, 7 linear seats att...
# 73  64 movable chairs with 15 tables. 134 linear s...
# 74  78 on benches and chairs. Also, the café provi...
# 75  Yes- 24 small wooden bench seats located at el...
# 76            15 chairs, 5 tables, 50' linear seating
# 77                                           76 seats
#
#                                          food_service                 art  \
# 0                                                  No                 Yes
# 1                                  In building below.                  No
# 2                                                 NaN                 NaN
# 3                                Multiple restaurants                  No
# 4                                                 Yes                  No
# 5                                                 Yes                 Yes
# 6                                                Yes.                 NaN
# 7                                                 Yes                  No
# 8                                                  No                 Yes
# 9                                                 Yes                 Yes
# 10                                                 No                  No
# 11                  café across street in hotel lobby                  No
# 12                                                Yes                  No
# 13                                                 No                 Yes
# 14                                                 No                  No
# 15                                    At ground level                 Yes
# 16                                                Yes                 Yes
# 17                                          Yes- Café                  No
# 18                             Sandwich shop and café                  No
# 19                                                Yes                  No
# 20                                                Yes                 Yes
# 21                                                 No                  No
# 22                                               Cart                  No
# 23                                                 No                 Yes
# 24                                                 No                  No
# 25                                          Starbucks                 Yes
# 26                                                 No                 Yes
# 27                                                 No                 Yes
# 28                                                NaN                 NaN
# 29                                                 No                 Yes
# 30                                                Yes                 Yes
# 31                                               Café                  No
# 32       Restaurant service nearby, starbucks outside                 Yes
# 33                                                NaN                 NaN
# 34  There is food service serving the commercial s...                  No
# 35                                                Yes                 Yes
# 36                                                 No                 Yes
# 37                                                Yes                 Yes
# 38                                                NaN                 NaN
# 39                                                Yes                  No
# 40                                                 No                  No
# 41                                          Yes, cafe                 Yes
# 42                                                 No                  No
# 43  None directly available, but some in adjacent ...                  No
# 44                                                 No                 Yes
# 45                                            2 cafes                  No
# 46                                           Yes café                 Yes
# 47                                                Yes                 Yes
# 48                                                 No                  No
# 49                                                 No                  No
# 50                                          Yes- Café                  No
# 51                                    Andytown Coffee  Sculpture outside.
# 52                     None, but food on the premises                  No
# 53                                                Yes                  No
# 54                           Yes; all along the alley                  No
# 55                                                Yes                 Yes
# 56                                                 No                  No
# 57                                                 No                 Yes
# 58                                                Yes                 Yes
# 59                                               Café                 Yes
# 60                                               Café                 Yes
# 61                                     Yes, café/deli                 NaN
# 62                             Sandwich shop and café                  No
# 63                                                 No                  No
# 64                                                 No                  No
# 65                                                NaN                 NaN
# 66                                                Yes                  No
# 67                                                Yes                 Yes
# 68                                                Yes                 Yes
# 69             Food provided along Leidesdorff Street                 Yes
# 70                                                Yes                  No
# 71  Several restaurants and cafes located within O...                 Yes
# 72                                                Yes                 Yes
# 73                                                Yes                 Yes
# 74                                               Café                 Yes
# 75                                                 No                  No
# 76                             Sandwich shop and café                  No
# 77                                                 No                 Yes
#
#                                             restrooms  \
# 0                                                  No
# 1                                                 Yes
# 2                                                 NaN
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                 NaN
# 7                                                  No
# 8                                                  No
# 9                                          Restaurant
# 10                                                 No
# 11                                                Yes
# 12                                                 No
# 13                                                 No
# 14                                                 No
# 15                                                 No
# 16                                                Yes
# 17                                                Yes
# 18                                                 No
# 19                                                 No
# 20                                                 No
# 21                                                Yes
# 22                                                 No
# 23                                                 No
# 24                                                Yes
# 25                                                 No
# 26  Yes, through main lobby at reception desk (ID ...
# 27   Located in hallway between lobby and indoor park
# 28                                                NaN
# 29                                                Yes
# 30                                                 No
# 31                                               None
# 32                                         Yes, hotel
# 33                                                NaN
# 34                                                 No
# 35                                                 No
# 36                                                Yes
# 37                                                 No
# 38                                                NaN
# 39                                                Yes
# 40                  Located on south side of building
# 41                                                Yes
# 42                                                 No
# 43              Would have had to go through security
# 44                                                 No
# 45                                                 No
# 46                                                 No
# 47                                                 No
# 48                                                Yes
# 49                                                 No
# 50                                                Yes
# 51                                                Yes
# 52                                                 No
# 53                                                 No
# 54                                                 No
# 55                       Yes. No restriction or lock.
# 56                                                 No
# 57                                                 No
# 58                                                 No
# 59                                                 No
# 60  Yes, through main lobby at reception desk (ID ...
# 61                                                Yes
# 62                                                 No
# 63                                                 No
# 64  Yes. Must present ID to guard in lobby to get ...
# 65                                                NaN
# 66                                                 No
# 67                                                Yes
# 68                                                 No
# 69              Yes. Must ask lobby attendant for key
# 70                                                 No
# 71  Yes, inside One Market Plaza at Mission St. en...
# 72                                                 No
# 73                                                Yes
# 74                                                 No
# 75                                                 No
# 76                                                 No
# 77                                                 No
#
#                                         accessibility  ...  \
# 0                                            Indirect  ...
# 1                                       Very Indirect  ...
# 2                                                 NaN  ...
# 3                                              Direct  ...
# 4                                              Direct  ...
# 5                                              Direct  ...
# 6                                                 NaN  ...
# 7                                              Direct  ...
# 8                                            Indirect  ...
# 9                                              Direct  ...
# 10                                        Less direct  ...
# 11                                             Direct  ...
# 12                                             Direct  ...
# 13                                             Direct  ...
# 14                                             Direct  ...
# 15                        Indirect, "grand" staircase  ...
# 16                                             Direct  ...
# 17                                             Direct  ...
# 18                                             Direct  ...
# 19                                             Direct  ...
# 20                                             Direct  ...
# 21                                             Direct  ...
# 22                                             Direct  ...
# 23                                           Indirect  ...
# 24                                           Indirect  ...
# 25                                             Direct  ...
# 26                                              13080  ...
# 27                                              13080  ...
# 28                                                NaN  ...
# 29                                             Direct  ...
# 30                                        Very Direct  ...
# 31                                             Direct  ...
# 32                                           Indirect  ...
# 33                                                NaN  ...
# 34  Direct. Gate at sidewalk open during daylight ...  ...
# 35         Direct for plaza. Indirect for indoor park  ...
# 36                                           Indirect  ...
# 37                                             Direct  ...
# 38                                             Direct  ...
# 39                                             Direct  ...
# 40                                              13080  ...
# 41                                             Direct  ...
# 42                                             Direct  ...
# 43                Slightly indirect (one side fenced)  ...
# 44                                           Indirect  ...
# 45                                             Direct  ...
# 46                                             Direct  ...
# 47                                             Direct  ...
# 48                                             Direct  ...
# 49                                             Direct  ...
# 50                                             Direct  ...
# 51  Through lobby to 7th floor of building or from...  ...
# 52                                      Very indirect  ...
# 53                                             Direct  ...
# 54                                        Very Direct  ...
# 55             Indirect for Atrium. Unknown for Plaza  ...
# 56                                             Direct  ...
# 57                                             Direct  ...
# 58                                   Direct, indirect  ...
# 59                                             Direct  ...
# 60                                           Indirect  ...
# 61                                                NaN  ...
# 62                                             Direct  ...
# 63                                             Direct  ...
# 64  Indirect. Must enter lobby, sign in, and take ...  ...
# 65                                                NaN  ...
# 66                                             Direct  ...
# 67                                             Direct  ...
# 68                                             Direct  ...
# 69                                           Indirect  ...
# 70                                             Direct  ...
# 71                                           Indirect  ...
# 72                                              Diect  ...
# 73                                             Direct  ...
# 74                                           Indirect  ...
# 75                                             Direct  ...
# 76                                             Direct  ...
# 77                                             Direct  ...
#
#    sf_find_neighborhoods current_police_districts  \
# 0                    108                        6
# 1                     19                        6
# 2                     32                        1
# 3                    108                        6
# 4                    108                        6
# 5                    108                        6
# 6                    108                        6
# 7                    108                        1
# 8                    108                        6
# 9                    108                        6
# 10                   108                        6
# 11                    32                        1
# 12                   108                        6
# 13                   108                        6
# 14                    32                        1
# 15                    32                        1
# 16                    30                        1
# 17                    32                        1
# 18                   108                        6
# 19                   108                        6
# 20                    32                        1
# 21                   108                        6
# 22                   108                        1
# 23                   108                        6
# 24                    32                        5
# 25                   108                        6
# 26                   108                        6
# 27                   108                        6
# 28                   108                        1
# 29                    21                        4
# 30                   108                        1
# 31                    32                        1
# 32                    32                        1
# 33                    19                        6
# 34                   104                        6
# 35                    32                        1
# 36                   104                        6
# 37                    32                        1
# 38                   108                        1
# 39                   108                        6
# 40                   108                        6
# 41                    32                        1
# 42                   108                        1
# 43                   108                        6
# 44                   108                        1
# 45                   108                        6
# 46                   104                        6
# 47                   108                        1
# 48                   108                        6
# 49                   108                        1
# 50                    32                        1
# 51                    32                        1
# 52                    32                        5
# 53                   108                        6
# 54                    19                        6
# 55                    32                        1
# 56                   108                        6
# 57                   108                        6
# 58                   108                        6
# 59                    32                        1
# 60                    32                        1
# 61                   108                        6
# 62                   108                        6
# 63                   108                        6
# 64                    19                        6
# 65                   108                        1
# 66                   108                        6
# 67                    32                        1
# 68                    32                        1
# 69                   108                        6
# 70                   108                        6
# 71                   108                        6
# 72                   108                        6
# 73                   108                        6
# 74                   108                        1
# 75                   108                        6
# 76                   108                        6
# 77                   108                        1
#
#    current_supervisor_districts analysis_neighborhoods food seating restroom  \
# 0                             3                      8  NaN     NaN      NaN
# 1                             3                      8    Y       Y     True
# 2                            10                      8  NaN     NaN      NaN
# 3                            10                      8    Y       Y      NaN
# 4                             3                      8    Y       Y      NaN
# 5                            10                      8    Y       Y      NaN
# 6                             3                      8    Y       Y      NaN
# 7                            10                      8    Y     NaN     True
# 8                             3                      8  NaN       Y      NaN
# 9                            10                      8    Y       Y      NaN
# 10                           10                      8  NaN       Y      NaN
# 11                           10                      8    Y       Y     True
# 12                           10                      8    Y       Y      NaN
# 13                            3                      8  NaN       Y      NaN
# 14                           10                      8  NaN       Y      NaN
# 15                           10                      8    Y       Y     True
# 16                           10                      8    Y       Y     True
# 17                           10                      8    Y       Y     True
# 18                            3                      8    Y       Y      NaN
# 19                           10                      8    Y     NaN      NaN
# 20                           10                      8    Y       Y     True
# 21                           10                      8  NaN       Y     True
# 22                           10                      8    Y       Y     True
# 23                            3                      8  NaN       Y     True
# 24                           10                     34  NaN       Y     True
# 25                            3                      8    Y       Y      NaN
# 26                           10                      8  NaN       Y     True
# 27                           10                      8  NaN       Y     True
# 28                           10                      8  NaN     NaN      NaN
# 29                           11                      9  NaN       Y     True
# 30                           10                      8    Y       Y     True
# 31                           10                      8    Y       Y      NaN
# 32                           10                      8    Y       Y     True
# 33                            3                      8  NaN     NaN      NaN
# 34                            3                      6    Y       Y      NaN
# 35                           10                      8    Y       Y      NaN
# 36                            3                      6    Y       Y     True
# 37                           10                      8    Y       Y     True
# 38                           10                      8  NaN     NaN      NaN
# 39                           10                      8    Y       Y     True
# 40                           10                      8  NaN       Y     True
# 41                           10                      8    Y       Y     True
# 42                           10                      8  NaN       Y     True
# 43                           10                      8  NaN       Y      NaN
# 44                           10                      8  NaN       Y      NaN
# 45                            3                      8    Y       Y      NaN
# 46                            3                      6    Y       Y     True
# 47                           10                      8    Y       Y     True
# 48                           10                      8  NaN     NaN     True
# 49                           10                      8  NaN       Y     True
# 50                           10                      8    Y       Y     True
# 51                           10                      8    Y       Y     True
# 52                           10                     34    Y       Y     True
# 53                           10                      8    Y       Y     True
# 54                            3                      8    Y       Y     True
# 55                           10                      8    Y       Y     True
# 56                           10                      8  NaN       Y      NaN
# 57                            3                      6    Y       Y      NaN
# 58                            3                      6    Y       Y     True
# 59                           10                      8    Y       Y     True
# 60                           10                      8    Y       Y     True
# 61                            3                      8  NaN     NaN      NaN
# 62                            3                      8    Y       Y      NaN
# 63                           10                      8  NaN       Y      NaN
# 64                            3                      8  NaN       Y     True
# 65                           10                      8  NaN     NaN      NaN
# 66                            3                      8    Y       Y      NaN
# 67                           10                      8    Y       Y     True
# 68                           10                      8    Y       Y      NaN
# 69                            3                      8    Y       Y     True
# 70                            3                      6    Y       Y      NaN
# 71                           10                      8    Y       Y     True
# 72                            3                      8    Y       Y      NaN
# 73                           10                      8    Y       Y     True
# 74                           10                      8    Y       Y     True
# 75                            3                      8  NaN       Y     True
# 76                            3                      8    Y       Y      NaN
# 77                           10                      8  NaN       Y     True
#
#                                      amenities indoor special_amenities
# 0                                          NaN    NaN               NaN
# 1                                          NaN    NaN               NaN
# 2                                          NaN    NaN               NaN
# 3                                          NaN    NaN               NaN
# 4                                          NaN    NaN               NaN
# 5                                          NaN    NaN               NaN
# 6                                          NaN    NaN               NaN
# 7                                          NaN    NaN               NaN
# 8                                          NaN    NaN               NaN
# 9                                          NaN    NaN               NaN
# 10                                         NaN    NaN               NaN
# 11                                         NaN    NaN               NaN
# 12                                         NaN    NaN               NaN
# 13                                         NaN    NaN               NaN
# 14                                         NaN    NaN               NaN
# 15                                         NaN    NaN               NaN
# 16                                         NaN    NaN               NaN
# 17                         Café area with wifi   True              True
# 18                                         NaN    NaN               NaN
# 19                                         NaN    NaN               NaN
# 20                                         NaN    NaN               NaN
# 21                                         NaN    NaN               NaN
# 22                                         NaN    NaN               NaN
# 23                                         NaN    NaN               NaN
# 24                                         NaN    NaN               NaN
# 25                                         NaN    NaN               NaN
# 26                                         NaN   True               NaN
# 27  Games: giant Connect4, ping pong, cornhole   True              True
# 28                                         NaN    NaN               NaN
# 29                                         NaN   True               NaN
# 30                                         NaN    NaN               NaN
# 31                                         NaN    NaN               NaN
# 32                                         NaN    NaN               NaN
# 33                                         NaN    NaN               NaN
# 34                                         NaN    NaN               NaN
# 35                                         NaN   True               NaN
# 36                                         NaN    NaN               NaN
# 37                                         NaN    NaN               NaN
# 38                                         NaN    NaN               NaN
# 39                                         NaN    NaN               NaN
# 40                                         NaN    NaN               NaN
# 41                                        Wifi   True              True
# 42                                         NaN    NaN               NaN
# 43                                         NaN    NaN               NaN
# 44                                         NaN   True               NaN
# 45                                         NaN    NaN               NaN
# 46                                         NaN    NaN               NaN
# 47                                         NaN    NaN               NaN
# 48                                         NaN    NaN               NaN
# 49                                         NaN    NaN               NaN
# 50                                         NaN    NaN               NaN
# 51                                         NaN   True               NaN
# 52                                         NaN    NaN               NaN
# 53                                         NaN    NaN               NaN
# 54                                         NaN    NaN               NaN
# 55                                         NaN   True               NaN
# 56                                Amphitheater   True              True
# 57                                         NaN    NaN               NaN
# 58                                         NaN    NaN               NaN
# 59                                         NaN    NaN               NaN
# 60                                         NaN   True               NaN
# 61                                         NaN    NaN               NaN
# 62                                         NaN    NaN               NaN
# 63                                         NaN    NaN               NaN
# 64                                         NaN    NaN               NaN
# 65                                         NaN    NaN               NaN
# 66                                         NaN    NaN               NaN
# 67                                         NaN    NaN               NaN
# 68                                         NaN    NaN               NaN
# 69                                         NaN    NaN               NaN
# 70                                         NaN    NaN               NaN
# 71                                         NaN   True               NaN
# 72                      Solar charging station    NaN              True
# 73                                         NaN   True               NaN
# 74                                         NaN   True               NaN
# 75                                         NaN    NaN               NaN
# 76                                         NaN    NaN               NaN
# 77                                         NaN    NaN               NaN
#
# [78 rows x 42 columns]

# %%
park_scores_df
# Out:
#     parkid   psa                         park      fq                score
# 0       86  PSA4             Carl Larsen Park  FY05Q3  0.79500000000000004
# 1       13  PSA4    Junipero Serra Playground  FY05Q3  0.95699999999999996
# 2        9  PSA4       Rolph Nicol Playground  FY05Q3  0.86399999999999999
# 3      117  PSA2                 Alamo Square  FY05Q4  0.85699999999999998
# 4       60  PSA6     Jose Coronado Playground  FY05Q4  0.85899999999999999
# ..     ...   ...                          ...     ...                  ...
# 995    148  PSA1      Michelangelo Playground  FY08Q2  0.96299999999999997
# 996    109  PSA1  Presidio Heights Playground  FY08Q2  0.90700000000000003
# 997    170  PSA1            Woh Hei Yuen Park  FY08Q2  0.92300000000000004
# 998    182  PSA2      Fillmore-Turk Mini Park  FY08Q2  0.63600000000000001
# 999    117  PSA2                 Alamo Square  FY08Q2  0.85499999999999998
#
# [1000 rows x 5 columns]

# %%
private_open_spaces_df.set_index(':@computed_region_yftq_j783').join(park_scores_df.set_index('parkid')).to_csv('temp.csv')

# %%
ps =private_open_spaces[0]
ps
# Out:
# {'name': '1 Bush Street',
#  'popos_address': '1 Bush Street',
#  'hours': 'Open at all times',
#  'type': 'Urban Garden',
#  'landscaping': 'Willow Trees and planting. Interseting architectural design',
#  'seating_no': 'None besides steps.',
#  'food_service': 'No',
#  'art': 'Yes',
#  'restrooms': 'No',
#  'accessibility': 'Indirect',
#  'location': 'Below street level',
#  'year': '1959',
#  'description': 'This Urban Garden provides a sunken space featuring a water fountain. Space is accessed with stairs from Bush Street and curved walkways from Market street.',
#  'seating_and_tables': 'N',
#  'hours_type': 'Open At All Times',
#  'subject_to_downtown_pln': 'No',
#  'signage': 'None',
#  'block_num': '0290',
#  'lot_num': '011',
#  'parcel_num': '0290011',
#  'the_geom': {'type': 'Point', 'coordinates': [-122.40045257, 37.79098054]},
#  ':@computed_region_6qbp_sg9q': '108',
#  ':@computed_region_qgnn_b9vv': '6',
#  ':@computed_region_26cr_cadq': '3',
#  ':@computed_region_ajp5_b2md': '8',
#  ':@computed_region_rxqg_mtj9': '10',
#  ':@computed_region_yftq_j783': '4',
#  ':@computed_region_jx4q_fizf': '1',
#  ':@computed_region_bh8s_q3mv': '28854',
#  ':@computed_region_jwn9_ihcz': '108',
#  'latitude': -122.40045257,
#  'longitude': 37.79098054,
#  'sf_find_neighborhoods': '108',
#  'current_police_districts': '6',
#  'current_supervisor_districts': '3',
#  'analysis_neighborhoods': '8'}

# %%
PrivateOpenSpaces(**ps)
# Out:
# PrivateOpenSpaces(id=None, name='1 Bush Street', popos_address='1 Bush Street', hours='Open at all times', type='Urban Garden', landscaping='Willow Trees and planting. Interseting architectural design', seating_no='None besides steps.', food_service='No', art='Yes', restrooms='No', accessibility='Indirect', location='Below street level', year=1959, description='This Urban Garden provides a sunken space featuring a water fountain. Space is accessed with stairs from Bush Street and curved walkways from Market street.', hours_type='Open At All Times', subject_to_downtown_pln='No', signage='None', block_num=290, lot_num=11, parcel_num=290011, latitude='-122.40045257', longitude='37.79098054', sf_find_neighborhoods=108, current_police_districts=6, current_supervisor_districts=3, analysis_neighborhoods=8)

# %%
from get_data import insert_into_db

# %%
fl = film_locations[0:2]
fl

# %%
insert_into_db(fl, FilmLocations)

# %%
film_locations_df[film_locations_df['title'].isna()]

# %%
properties_df

# %%
# film_locations_df['location_cleaned'] = film_locations_df['locations'].str.split("(")[0]
film_locations_df[['location_1', 'location_2']] = film_locations_df.locations.str.split("(", expand = True)
film_locations_df['location_2'].replace('\)','', inplace=True, regex=True)

# %%
film_locations_df

# %%
film_locations['locations']

# %%
properties[0]

# %%
private_open_spaces[0]
